# %%
import pandas as pd
import numpy as np


# with open("/home/stlk/Desktop/DigEc_data_additional/worldcitiespop.txt", encoding='utf-8') as f:
    

d = pd.read_csv("/home/stlk/Desktop/DigEc_data_additional/worldcitiespop.txt", encoding='latin1', sep=',')
# Out:
# /home/stlk/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# d = d.dropna(axis="1")
d.dropna?

# %%
# d.City.unique

# d[d.City == "moscow"]

#g = d.groupby(["AccentCity", "Population"])

d.sort_values(["AccentCity", "Population"], ascending=False).groupby('AccentCity').head(3)

# g = d['AccentCity'].groupby(level=0, group_keys=False)
# res = g.apply(lambda x: x.order(ascending=False).head(3))
# Out:
#         Country                      City                AccentCity Region  \
# 1751422      ma             in bou chella             ïn Bou Chella     58
# 839789       eg           aabd el-gilil           âAbd el-Gilil     08
# 1503439      is               Þonglabakki               Þönglabakki     32
# 1503443      is                  Þorshofn                  Þórshöfn     21
# 1503442      is             Þoroddsstaður             Þóroddsstaður     32
# 1503449      is                Þykkvibaer                 Þykkvibær     23
# 1503450      is                Þykkvibaer                 Þykkvibær     37
# 1503447      is      Þykkvabaejarklaustur       Þykkvabæjarklaustur     37
# 1503448      is       Þykkvabejarklaustur       Þykkvabejarklaustur     37
# 1503446      is                     Þvera                     Þverá     32
# 1503444      is                Þrestbakki                Þrestbakki     30
# 1503445      is                Þrestbakki                Þrestbakki     37
# 1503441      is               Þorlakshofn               Þorlákshöfn      3
# 1503440      is            Þorkotlustaðir            Þorkötlustaðir     10
# 1503438      is                Þjorsarbru                Þjórsárbrú      3
# 1503437      is                Þingvellir                Þingvellir      3
# 1503436      is                  Þingmuli                  Þingmúli     31
# 1503435      is                  Þingeyri                  Þingeyri     36
# 1503434      is                 Þingeyrar                 Þingeyrar      5
# 1503433      is                   Þingeri                   Þingeri     36
# 1503432      is         Þaralatursfjorður         Þaralátursfjörður     19
# 1064622      gr                     ypsos                     Ýpsos     25
# 1064371      gr                      ydra                      Ýdra     35
# 3110245      vn                      y ti                      Ý Tí     19
# 838764       ee                    uuvere                    Üüvere     14
# 2831402      tr                   uurunlu                   Üürünlü     16
# 838706       ee                    uudipa                    Üüdipä     14
# 838705       ee                    uudibe                    Üüdibe     14
# 2830757      tr                   ucuzler                   Üçüzler     63
# 2830756      tr                    ucuyuk                    Üçüyük     43
# ...         ...                       ...                       ...    ...
# 1849751      mr              'adel bagrou              'Adel Bagrou      1
# 975          af        'abdul wahab kalay        'Abdul Wahab Kalay      8
# 830          af        'abdul hakim kalay        'Abdul Hakim Kalay     23
# 1735822      ma             'abd al qader             'Abd al Qader     47
# 2664215      sy                 'aadeissa                 'Aadeïssa      3
# 1366990      iq             !fajji !fasan             !fajji !fasan     10
# 104262       al               zall-gjocaj               Zall-Gjoçaj     48
# 261952       bg              vzemen orman              Vzemen Orman     51
# 2682104      sy                 umm qusur                 Umm Qusur      1
# 3075585      ve          santa feliicitas          Santa Feliícitas     03
# 3074813      ve               san agustin               San Agustín     06
# 1373937      iq         qaryat ad dawayah         Qaryat ad Dawayah      1
# 1373941      iq   qaryat `ajimi as sabbar   Qaryat `Ajimi as Sabbar      1
# 1374235      iq         qaryat khatuniyah         Qaryat Khatuniyah      6
# 1098565      hr                     petar                     Petar     12
# 1960006      mz                  munhoque                  Munhoque      2
# 817883       dz             mechta charef             Mechta Charef     48
# 1096933      hr              mala paukova              Mala Paukova     14
# 1677847      lb           magharat `ubayd           Magharat `Ubayd      3
# 1371361      iq     madinat al habbaniyah     Madinat al Habbaniyah      1
# 3070220      ve            los higuerotes            Los Higuerotes     12
# 3068990      ve           las tres marias           Las Tres Marías     11
# 1368442      iq             hayy al akrad             Hayy al Akrad      1
# 275705       bo      estancia jokho pekhe      Estancia Jokho Pekhe      5
# 3063267      ve                el quemado                El Quemado     23
# 3062244      ve                 el islero                 El Islero     12
# 3061907      ve                  el eneal                  El Eneal     18
# 1093257      hr                donji kraj                Donji Kraj      3
# 1949735      mz            chefe muzamane            Chefe Muzamane      2
# 1673702      lb              bab el ahmar              Bâb el Ahmar      1
#
#          Population   Latitude   Longitude
# 1751422         NaN  34.416195   -4.674472
# 839789          NaN  29.383333   31.233333
# 1503439         NaN  66.150000  -18.133333
# 1503443         NaN  66.200000  -15.333333
# 1503442         NaN  65.850000  -17.550000
# 1503449         NaN  63.750000  -20.616667
# 1503450         NaN  63.500000  -18.366667
# 1503447         NaN  63.500000  -18.366667
# 1503448         NaN  63.500000  -18.366667
# 1503446         NaN  65.733333  -17.250000
# 1503444         NaN  65.316667  -21.200000
# 1503445         NaN  63.833333  -18.016667
# 1503441         NaN  63.850000  -21.366667
# 1503440         NaN  63.833333  -22.400000
# 1503438         NaN  63.933333  -20.666667
# 1503437         NaN  64.250000  -21.116667
# 1503436         NaN  65.033333  -14.616667
# 1503435         NaN  65.866667  -23.500000
# 1503434         NaN  65.550000  -20.416667
# 1503433         NaN  65.866667  -23.500000
# 1503432         NaN  66.250000  -22.150000
# 1064622         NaN  39.694722   19.836667
# 1064371         NaN  37.347778   23.458889
# 3110245         NaN  22.666667  103.583333
# 838764          NaN  58.415556   22.976667
# 2831402         NaN  40.201021   28.875860
# 838706          NaN  58.142500   22.236389
# 838705          NaN  58.142500   22.236389
# 2830757         NaN  37.550000   38.933333
# 2830756         NaN  39.118611   30.039444
# ...             ...        ...         ...
# 1849751         NaN  15.566667   -7.116667
# 975             NaN  32.668743   67.754669
# 830             NaN  31.096111   66.621111
# 1735822         NaN  31.763114   -9.046055
# 2664215         NaN  32.823889   35.698889
# 1366990         NaN  34.841667   45.716667
# 104262          NaN  41.741667   20.153333
# 261952          NaN  42.100000   24.483333
# 2682104         NaN  36.241667   40.906111
# 3075585         NaN   7.243333  -69.960000
# 3074813         NaN   7.310000  -66.118333
# 1373937         NaN  33.445278   43.812778
# 1373941         NaN  33.450278   43.891389
# 1374235         NaN  32.608889   44.439167
# 1098565         NaN  45.090278   14.354722
# 1960006         NaN -24.869722   33.461667
# 817883          NaN  36.076389    6.276667
# 1096933         NaN  45.351389   16.491111
# 1677847         NaN  34.183333   35.750000
# 1371361         NaN  33.381944   43.577222
# 3070220         NaN   9.854444  -67.573889
# 3068990         NaN  10.379444  -70.608333
# 1368442         NaN  33.413611   43.273611
# 275705          NaN -18.211944  -68.921111
# 3063267         NaN   9.677778  -72.388333
# 3062244         NaN   7.881667  -65.821667
# 3061907         NaN   8.307222  -68.867222
# 1093257         NaN  42.430278   18.492222
# 1949735         NaN -22.815833   31.958056
# 1673702         NaN  33.529167   35.825000
#
# [2815435 rows x 7 columns]
